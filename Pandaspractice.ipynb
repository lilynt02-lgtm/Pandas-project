# %% [markdown]
# <a href="https://colab.research.google.com/github/lilynt02-lgtm/Pandas-project/blob/main/Pandaspractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Enoncé
# Une étude sur la répartition de la population française en 2020.
#
# Deux jeux de données :
#
# - population.csv : contient la population pour chaque commune française pour plusieurs années de rencensement
# Lien : https://drive.google.com/uc?id=1SD1bXovlPb9HqcDbuO37Q9_J5GKXY6TL
#
# - noms_communes.csv : permet de faire le rapprochement entre le code de la commune et son nom
# Lien : https://drive.google.com/uc?id=1bqGzuT08FEzlCjTmpgw1eB4MksLVkyUh
#
# # Objectifs du TP évalué
# Nettoyez les données en vue de les rendre utilisables pour l'analyse. Vous devrez :
#
# - charger les données dans Pandas (ajouter le paramètre `low_memory=False` pour éviter les problèmes de types de données)
# - décrire le contenu des données (nombre de lignes / colonnes, valeurs manquantes)
# - rapprocher les deux tables via une jointure (fonction merge)
# - supprimer d'éventuelles colonnes inutiles (ex : colonne contenant toujours une même valeur)
# - identifier et nettoyer les valeurs aberrantes / manquantes
# - sélectionner les lignes pertinentes (année 2020)
# - supprimer les éventuels doublons (pour les identifier, utiliser `df.duplicated()`, et `df.drop_duplicates()`)
# - créer une nouvelle colonne département basée sur le code de la commune (utiliser la syntaxe `df['colonne'].str[:2]` pour extraire les deux premiers chiffres)
# - renommer les colonnes pour les rendre plus facilement compréhensibles
#
# Structurez votre notebook avec des cellules de code, et des cellules de texte indiquant le titre de chaque partie et vos réflexions.
#
# # Objectifs annexes
# On souhaite analyser la densité de population sur le territoire. Pour cela on utilise les données en open data de superficie des communes : https://www.observatoire-des-territoires.gouv.fr/superficie
#
# Télécharger sur votre Drive et importer dans le notebook les données de superficie. Vous pouvez vous appuyer sur le tutoriel suivant : https://saturncloud.io/blog/how-to-import-files-from-google-drive-to-colab/
#
# Joindre les données à celles préparées précédemment dans le TP. A l'aide de la population et de la superficie des communes, calculer la densité de population (nombre d'habitants / superficie).
#
# Quels sont les départements avec la densité de population la plus forte ?
